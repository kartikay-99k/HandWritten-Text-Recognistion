# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.2-203-g6371de8 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.8/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 120 --data dataset.yaml --weights yolov5s.pt --cache --device 0
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=120, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-203-g6371de8 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
from IPython.display import Image #this is to render predictions
Image(filename='/content/yolov5/runs/train/exp/val_batch0_labels.jpg', width=1000)

# %%
Image(filename='/content/yolov5/runs/train/exp/val_batch0_pred.jpg', width=1000)

# %%
# !python detect.py --source /content/data_page-0001.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/data_page-0001.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de8 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/data_page-0001.jpg: 640x512 1 HandWritten, 12.7ms
# Speed: 0.6ms pre-process, 12.7ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# !python detect.py --source /content/data_page-0002.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/data_page-0002.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de8 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/data_page-0002.jpg: 640x512 4 HandWrittens, 13.0ms
# Speed: 0.6ms pre-process, 13.0ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
# !python detect.py --source /content/data_page-0003.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/data_page-0003.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de8 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/data_page-0003.jpg: 640x512 2 HandWrittens, 11.4ms
# Speed: 0.5ms pre-process, 11.4ms inference, 1.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
# !python detect.py --source /content/data_page-0004.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/data_page-0004.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-203-g6371de8 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/data_page-0004.jpg: 640x512 2 HandWrittens, 12.9ms
# Speed: 0.6ms pre-process, 12.9ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5

# %%
# !python detect.py --source /content/44.jpg --weights /content/yolov5/runs/train/exp/weights/best.pt

# Image(filename='/content/yolov5/runs/detect/exp6/44.jpg', width=1000)

# %%
# !zip -r /content/file.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/.gitattributes (deflated 4%)
#   adding: content/yolov5/models/ (stored 0%)
#   adding: content/yolov5/models/tf.py (deflated 73%)
#   adding: content/yolov5/models/experimental.py (deflated 59%)
#   adding: content/yolov5/models/__pycache__/ (stored 0%)
#   adding: content/yolov5/models/__pycache__/common.cpython-37.pyc (deflated 57%)
#   adding: content/yolov5/models/__pycache__/__init__.cpython-37.pyc (deflated 26%)
#   adding: content/yolov5/models/__pycache__/experimental.cpython-37.pyc (deflated 45%)
#   adding: content/yolov5/models/__pycache__/yolo.cpython-37.pyc (deflated 49%)
#   adding: content/yolov5/models/yolov5s.yaml (deflated 60%)
#   adding: content/yolov5/models/yolov5m.yaml (deflated 60%)
#   adding: content/yolov5/models/__init__.py (stored 0%)
#   adding: content/yolov5/models/yolo.py (deflated 67%)
#   adding: content/yolov5/models/segment/ (stored 0%)
# ...

# %%
from google.colab import files
files.download("/content/file.zip")
